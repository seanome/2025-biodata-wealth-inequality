# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import polars as pl
import seaborn as sns
from ipywidgets import widgets

# %%
uniprot_sprot = pd.read_parquet("../data/uniprot_sprot_taxonomy_summary.parquet")
print(uniprot_sprot.shape)


def merge_microbes(species_type):
    if species_type in {"Bacteria", "Archaea", "Viruses"}:
        return "Microbial"
    else:
        return species_type.title()


def assign_superdomain(species_type):
    if species_type == "Viruses":
        return "Non-cellular Life"
    else:
        return "Cellular Life"


def assign_domain(species_type):
    if species_type in {"Bacteria", "Archaea", "Viruses"}:
        return species_type
    else:
        return "Eukaryota"


def assign_kingdom(species_type):
    if species_type in {"Bacteria", "Archaea"}:
        return "Monera"
    else:
        return species_type


uniprot_sprot["type_merge_microbes"] = uniprot_sprot["type"].apply(merge_microbes)
uniprot_sprot["superdomain"] = uniprot_sprot["type"].apply(assign_superdomain)
uniprot_sprot["domain"] = uniprot_sprot["type"].apply(assign_domain)
uniprot_sprot["kingdom"] = uniprot_sprot["type"].apply(assign_kingdom)
uniprot_sprot.head()
# Out:
# (14755, 7)
#                                             organism  reviewed_count  \
# 0                                       Homo sapiens           20417
# 1                                       Mus musculus           17228
# 2                               Arabidopsis thaliana           16396
# 3                                  Rattus norvegicus            8209
# 4  Saccharomyces cerevisiae (strain ATCC 204508 /...            6733
#
#    unreviewed_count  pdb_structures_count  organism_id  \
# 0                 0                  8511         9606
# 1                 0                  2458        10090
# 2                 0                  1057         3702
# 3                 0                   724        10116
# 4                 0                  2114       559292
#
#                                              lineage    type  \
# 0  Catarrhini; Chordata; Craniata; Euarchontoglir...  Animal
# 1  Chordata; Craniata; Euarchontoglires; Eukaryot...  Animal
# 2  Arabidopsis; Brassicaceae; Brassicales; Cameli...   Plant
# 3  Chordata; Craniata; Euarchontoglires; Eukaryot...  Animal
# 4  Ascomycota; Dikarya; Eukaryota; Fungi; Sacchar...   Fungi
#
#   type_merge_microbes    superdomain     domain kingdom
# 0              Animal  Cellular Life  Eukaryota  Animal
# 1              Animal  Cellular Life  Eukaryota  Animal
# 2               Plant  Cellular Life  Eukaryota   Plant
# 3              Animal  Cellular Life  Eukaryota  Animal
# 4               Fungi  Cellular Life  Eukaryota   Fungi

# %% [markdown]
# ### What percentage of the structures are from human?

# %%
uniprot_sprot.pdb_structures_count.sum()
# Out:
# np.uint64(36768)

# %%
8511 / uniprot_sprot.pdb_structures_count.sum()
# Out:
# np.float64(0.2314784595300261)

# %%
uniprot_sprot.to_parquet("../data/uniprot_sprot_taxonomy_summary_with_domains.parquet")

# %%
uniprot_sprot.sort_values("reviewed_count", ascending=False).head(10)
# Out:
#                                             organism  reviewed_count  \
# 0                                       Homo sapiens           20417
# 1                                       Mus musculus           17228
# 2                               Arabidopsis thaliana           16396
# 3                                  Rattus norvegicus            8209
# 4  Saccharomyces cerevisiae (strain ATCC 204508 /...            6733
# 5                                         Bos taurus            6048
# 6  Schizosaccharomyces pombe (strain 972 / ATCC 2...            5121
# 7                      Escherichia coli (strain K12)            4531
# 8                             Caenorhabditis elegans            4489
# 9                       Oryza sativa subsp. japonica            4191
#
#    unreviewed_count  pdb_structures_count  organism_id  \
# 0                 0                  8511         9606
# 1                 0                  2458        10090
# 2                 0                  1057         3702
# 3                 0                   724        10116
# 4                 0                  2114       559292
# 5                 0                   560         9913
# 6                 0                   425       284812
# 7                 0                  1732        83333
# 8                 0                   278         6239
# 9                 0                   103        39947
#
#                                              lineage      type  \
# 0  Catarrhini; Chordata; Craniata; Euarchontoglir...    Animal
# 1  Chordata; Craniata; Euarchontoglires; Eukaryot...    Animal
# 2  Arabidopsis; Brassicaceae; Brassicales; Cameli...     Plant
# 3  Chordata; Craniata; Euarchontoglires; Eukaryot...    Animal
# 4  Ascomycota; Dikarya; Eukaryota; Fungi; Sacchar...     Fungi
# 5  Artiodactyla; Bos; Bovidae; Bovinae; Chordata;...    Animal
# 6  Ascomycota; Dikarya; Eukaryota; Fungi; Schizos...     Fungi
# 7  Bacteria; Enterobacterales; Enterobacteriaceae...  Bacteria
# 8  Caenorhabditis; Chromadorea; Ecdysozoa; Eukary...    Animal
# 9  BOP clade; Embryophyta; Eukaryota; Liliopsida;...     Plant
#
#   type_merge_microbes    superdomain     domain kingdom
# 0              Animal  Cellular Life  Eukaryota  Animal
# 1              Animal  Cellular Life  Eukaryota  Animal
# 2               Plant  Cellular Life  Eukaryota   Plant
# 3              Animal  Cellular Life  Eukaryota  Animal
# 4               Fungi  Cellular Life  Eukaryota   Fungi
# 5              Animal  Cellular Life  Eukaryota  Animal
# 6               Fungi  Cellular Life  Eukaryota   Fungi
# 7           Microbial  Cellular Life   Bacteria  Monera
# 8              Animal  Cellular Life  Eukaryota  Animal
# 9               Plant  Cellular Life  Eukaryota   Plant

# %%
uniprot_sprot.sort_values("pdb_structures_count", ascending=False).head(10)
# Out:
#                                              organism  reviewed_count  \
# 0                                        Homo sapiens           20417
# 1                                        Mus musculus           17228
# 4   Saccharomyces cerevisiae (strain ATCC 204508 /...            6733
# 7                       Escherichia coli (strain K12)            4531
# 2                                Arabidopsis thaliana           16396
# 10                     Bacillus subtilis (strain 168)            4191
# 15  Mycobacterium tuberculosis (strain ATCC 25618 ...            2325
# 3                                   Rattus norvegicus            8209
# 5                                          Bos taurus            6048
# 12                            Drosophila melanogaster            3816
#
#     unreviewed_count  pdb_structures_count  organism_id  \
# 0                  0                  8511         9606
# 1                  0                  2458        10090
# 4                  0                  2114       559292
# 7                  0                  1732        83333
# 2                  0                  1057         3702
# 10                 0                   753       224308
# 15                 0                   742        83332
# 3                  0                   724        10116
# 5                  0                   560         9913
# 12                 0                   455         7227
#
#                                               lineage      type  \
# 0   Catarrhini; Chordata; Craniata; Euarchontoglir...    Animal
# 1   Chordata; Craniata; Euarchontoglires; Eukaryot...    Animal
# 4   Ascomycota; Dikarya; Eukaryota; Fungi; Sacchar...     Fungi
# 7   Bacteria; Enterobacterales; Enterobacteriaceae...  Bacteria
# 2   Arabidopsis; Brassicaceae; Brassicales; Cameli...     Plant
# 10  Bacillaceae; Bacillales; Bacillati; Bacilli; B...  Bacteria
# 15  Actinomycetes; Actinomycetota; Bacillati; Bact...  Bacteria
# 3   Chordata; Craniata; Euarchontoglires; Eukaryot...    Animal
# 5   Artiodactyla; Bos; Bovidae; Bovinae; Chordata;...    Animal
# 12  Arthropoda; Brachycera; Diptera; Drosophila; D...    Animal
#
#    type_merge_microbes    superdomain     domain kingdom
# 0               Animal  Cellular Life  Eukaryota  Animal
# 1               Animal  Cellular Life  Eukaryota  Animal
# 4                Fungi  Cellular Life  Eukaryota   Fungi
# 7            Microbial  Cellular Life   Bacteria  Monera
# 2                Plant  Cellular Life  Eukaryota   Plant
# 10           Microbial  Cellular Life   Bacteria  Monera
# 15           Microbial  Cellular Life   Bacteria  Monera
# 3               Animal  Cellular Life  Eukaryota  Animal
# 5               Animal  Cellular Life  Eukaryota  Animal
# 12              Animal  Cellular Life  Eukaryota  Animal

# %%
uniprot_sprot.groupby(["superdomain", "domain", "kingdom"]).size()
# Out:
# superdomain        domain     kingdom
# Cellular Life      Archaea    Monera              236
#                    Bacteria   Monera             3353
#                    Eukaryota  Animal             4967
#                               Fungi               871
#                               Plant              2194
#                               other Eukaryota     368
# Non-cellular Life  Viruses    Viruses            2766
# dtype: int64

# %%
# uniprot_sprot.sort_values("n_proteins", ascending=False).head()

# %%
uniprot_sprot_summarized_per_organism = uniprot_sprot.groupby("organism").agg(
    {
        "reviewed_count": "sum",
        "organism": "first",
        "organism_id": "first",
        "lineage": "first",
        "type": "first",
        "type_merge_microbes": "first",
        "pdb_structures_count": "sum",
    }
)
print(uniprot_sprot_summarized_per_organism.shape)
uniprot_sprot_summarized_per_organism.sort_values("reviewed_count", ascending=False)
# Out:
# (14755, 7)
#                                                     reviewed_count  \
# organism
# Homo sapiens                                                 20417
# Mus musculus                                                 17228
# Arabidopsis thaliana                                         16396
# Rattus norvegicus                                             8209
# Saccharomyces cerevisiae (strain ATCC 204508 / ...            6733
# ...                                                            ...
# Plasmodium falciparum (isolate FCH-5)                            1
# Lilium michiganense                                              1
# Lilium regale                                                    1
# Foot-and-mouth disease virus (isolate Bovine/Br...               1
# AKT8 murine leukemia virus                                       1
#
#                                                                                              organism  \
# organism
# Homo sapiens                                                                             Homo sapiens
# Mus musculus                                                                             Mus musculus
# Arabidopsis thaliana                                                             Arabidopsis thaliana
# Rattus norvegicus                                                                   Rattus norvegicus
# Saccharomyces cerevisiae (strain ATCC 204508 / ...  Saccharomyces cerevisiae (strain ATCC 204508 /...
# ...                                                                                               ...
# Plasmodium falciparum (isolate FCH-5)                           Plasmodium falciparum (isolate FCH-5)
# Lilium michiganense                                                               Lilium michiganense
# Lilium regale                                                                           Lilium regale
# Foot-and-mouth disease virus (isolate Bovine/Br...  Foot-and-mouth disease virus (isolate Bovine/B...
# AKT8 murine leukemia virus                                                 AKT8 murine leukemia virus
#
#                                                     organism_id  \
# organism
# Homo sapiens                                               9606
# Mus musculus                                              10090
# Arabidopsis thaliana                                       3702
# Rattus norvegicus                                         10116
# Saccharomyces cerevisiae (strain ATCC 204508 / ...       559292
# ...                                                         ...
# Plasmodium falciparum (isolate FCH-5)                    132416
# Lilium michiganense                                       84049
# Lilium regale                                             82328
# Foot-and-mouth disease virus (isolate Bovine/Br...        12115
# AKT8 murine leukemia virus                                11790
#
#                                                                                               lineage  \
# organism
# Homo sapiens                                        Catarrhini; Chordata; Craniata; Euarchontoglir...
# Mus musculus                                        Chordata; Craniata; Euarchontoglires; Eukaryot...
# Arabidopsis thaliana                                Arabidopsis; Brassicaceae; Brassicales; Cameli...
# Rattus norvegicus                                   Chordata; Craniata; Euarchontoglires; Eukaryot...
# Saccharomyces cerevisiae (strain ATCC 204508 / ...  Ascomycota; Dikarya; Eukaryota; Fungi; Sacchar...
# ...                                                                                               ...
# Plasmodium falciparum (isolate FCH-5)               Aconoidasida; Alveolata; Apicomplexa; Eukaryot...
# Lilium michiganense                                 Embryophyta; Eukaryota; Liliaceae; Liliales; L...
# Lilium regale                                       Embryophyta; Eukaryota; Liliaceae; Liliales; L...
# Foot-and-mouth disease virus (isolate Bovine/Br...  Aphthovirus; Caphthovirinae; Foot-and-mouth di...
# AKT8 murine leukemia virus                          Artverviricota; Gammaretrovirus; Murine leukem...
#
#                                                                type  \
# organism
# Homo sapiens                                                 Animal
# Mus musculus                                                 Animal
# Arabidopsis thaliana                                          Plant
# Rattus norvegicus                                            Animal
# Saccharomyces cerevisiae (strain ATCC 204508 / ...            Fungi
# ...                                                             ...
# Plasmodium falciparum (isolate FCH-5)               other Eukaryota
# Lilium michiganense                                           Plant
# Lilium regale                                                 Plant
# Foot-and-mouth disease virus (isolate Bovine/Br...          Viruses
# AKT8 murine leukemia virus                                  Viruses
#
#                                                    type_merge_microbes  \
# organism
# Homo sapiens                                                    Animal
# Mus musculus                                                    Animal
# Arabidopsis thaliana                                             Plant
# Rattus norvegicus                                               Animal
# Saccharomyces cerevisiae (strain ATCC 204508 / ...               Fungi
# ...                                                                ...
# Plasmodium falciparum (isolate FCH-5)                  Other Eukaryota
# Lilium michiganense                                              Plant
# Lilium regale                                                    Plant
# Foot-and-mouth disease virus (isolate Bovine/Br...           Microbial
# AKT8 murine leukemia virus                                   Microbial
#
#                                                     pdb_structures_count
# organism
# Homo sapiens                                                        8511
# Mus musculus                                                        2458
# Arabidopsis thaliana                                                1057
# Rattus norvegicus                                                    724
# Saccharomyces cerevisiae (strain ATCC 204508 / ...                  2114
# ...                                                                  ...
# Plasmodium falciparum (isolate FCH-5)                                  0
# Lilium michiganense                                                    0
# Lilium regale                                                          0
# Foot-and-mouth disease virus (isolate Bovine/Br...                     1
# AKT8 murine leukemia virus                                             0
#
# [14755 rows x 7 columns]

# %%
uniprot_sprot_n_proteins_per_organism = (
    uniprot_sprot.groupby("organism").reviewed_count.sum().sort_values(ascending=False)
)
uniprot_sprot_n_proteins_per_organism.head(10)
# Out:
# organism
# Homo sapiens                                             20417
# Mus musculus                                             17228
# Arabidopsis thaliana                                     16396
# Rattus norvegicus                                         8209
# Saccharomyces cerevisiae (strain ATCC 204508 / S288c)     6733
# Bos taurus                                                6048
# Schizosaccharomyces pombe (strain 972 / ATCC 24843)       5121
# Escherichia coli (strain K12)                             4531
# Caenorhabditis elegans                                    4489
# Bacillus subtilis (strain 168)                            4191
# Name: reviewed_count, dtype: uint32

# %%
uniprot_sprot.type_merge_microbes.value_counts()
# Out:
# type_merge_microbes
# Microbial          6355
# Animal             4967
# Plant              2194
# Fungi               871
# Other Eukaryota     368
# Name: count, dtype: int64

# %%
uniprot_sprot_n_proteins = uniprot_sprot.groupby(
    "type_merge_microbes"
).reviewed_count.sum()
uniprot_sprot_n_proteins.name = "n_proteins_sprot"
uniprot_sprot_n_proteins
# Out:
# type_merge_microbes
# Animal             110164
# Fungi               37406
# Microbial          373984
# Other Eukaryota      9540
# Plant               41876
# Name: n_proteins_sprot, dtype: uint32

# %% [markdown]
# ### Sanity check that this is equal to the expected number of UniProt/SwissProt Proteins for Release  2025_01

# %%
assert uniprot_sprot_n_proteins.sum() == 572970
